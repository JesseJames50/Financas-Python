# %% [markdown]
# <a href="https://colab.research.google.com/github/JesseJames50/Financas-Python/blob/main/Trader_Biblioteca_Yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalação da biblioteca yfinance
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 18.0 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
#Importanto a biblioteca yfinance
import yfinance as yf

# %%
#Plotando um gráfico com os dados do Facebook (FB)
yf.download('FB').Close.plot()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#Filtrando os dados por determinado período de tempo da empresa APLE
data = yf.download('AAPL', start='2017-01-01',end='2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#Exibindo os dados
data.head(10)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-01-03  28.950001  29.082500  28.690001  29.037500  27.257647  115127600
# 2017-01-04  28.962500  29.127501  28.937500  29.004999  27.227135   84472400
# 2017-01-05  28.980000  29.215000  28.952499  29.152500  27.365593   88774400
# 2017-01-06  29.195000  29.540001  29.117500  29.477501  27.670679  127007600
# 2017-01-09  29.487499  29.857500  29.485001  29.747499  27.924120  134247600
# 2017-01-10  29.692499  29.844999  29.575001  29.777500  27.952286   97848400
# 2017-01-11  29.684999  29.982500  29.650000  29.937500  28.102480  110354400
# 2017-01-12  29.725000  29.825001  29.552500  29.812500  27.985138  108344800
# 2017-01-13  29.777500  29.905001  29.702499  29.760000  27.935862  104447600
# 2017-01-17  29.584999  30.059999  29.555000  30.000000  28.161146  137759200

# %% [markdown]
# # Outros dados sobre os papéis
# ## Basta passar o ticker dentro da função.

# %%
#Coletando os dados fundamentalistas da Coca-Cola
coke = yf.Ticker('KO')

# %%
# informações do papel
coke.info
# Out:
# {'52WeekChange': 0.1439476,
#  'SandP52WeekChange': -0.117819905,
#  'address1': 'One Coca-Cola Plaza',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 62.9,
#  'askSize': 3000,
#  'averageDailyVolume10Day': 13595310,
#  'averageVolume': 18322696,
#  'averageVolume10days': 13595310,
#  'beta': 0.557684,
#  'beta3Year': None,
#  'bid': 62.75,
#  'bidSize': 1000,
#  'bookValue': 5.737,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Atlanta',
#  'coinMarketCapLink': None,
#  'companyOfficers': [],
#  'country': 'United States',
#  'currency': 'USD',
#  'currentPrice': 62.94,
#  'currentRatio': 1.179,
#  'dateShortInterest': 1655251200,
#  'dayHigh': 63.46,
#  'dayLow': 62.59,
#  'debtToEquity': 157.01,
#  'dividendRate': 1.76,
#  'dividendYield': 0.0279,
#  'earningsGrowth': 0.231,
#  'earningsQuarterlyGrowth': 0.239,
#  'ebitda': 13157999616,
#  'ebitdaMargins': 0.32792,
#  'enterpriseToEbitda': 23.37,
# ...

# %%
# Acessar algum dado das informações
coke.info['bid']
# Out:
# 62.75

# %%
# Retorna histórico de dividendos, stock splits, etc
#period = 'max' retorna o histórico desde a existência do papel
hist = coke.history(period = 'max')

# %%
# Verificando os ultimos registros do Dataframe
hist.tail()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2022-07-05  64.180000  64.180000  62.419998  63.279999  15921200        0.0
# 2022-07-06  63.599998  64.089996  63.189999  63.410000  13450500        0.0
# 2022-07-07  63.259998  63.580002  62.700001  62.910000  14828400        0.0
# 2022-07-08  63.029999  63.419998  62.880001  63.139999  11308900        0.0
# 2022-07-11  62.990002  63.459999  62.590000  62.939999  12702100        0.0
#
#             Stock Splits
# Date
# 2022-07-05           0.0
# 2022-07-06           0.0
# 2022-07-07           0.0
# 2022-07-08           0.0
# 2022-07-11           0.0

# %%
# Plotando o gráfico do histórico de fechamentos
hist.Close.plot()

# %%
# Plotando o gráfico do histórico de dividendos
hist.Dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Verificando o tamanho do arquivo (linhas, colunas)
hist.shape
# Out:
# (15235, 7)

# %%
# Plotando o gráfico do histórico de dividendos pelo número de série
hist.Dividends.iloc[14113:15214].plot()

# %%
# Mostrar eventos de liquidez actions (dividendos, splits)
coke.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1962-03-13   0.001563           0.0
# 1962-06-11   0.001563           0.0
# 1962-09-11   0.001563           0.0
# 1962-11-28   0.001563           0.0
# 1963-03-11   0.001758           0.0
# ...               ...           ...
# 2021-06-14   0.420000           0.0
# 2021-09-14   0.420000           0.0
# 2021-11-30   0.420000           0.0
# 2022-03-14   0.440000           0.0
# 2022-06-14   0.440000           0.0
#
# [249 rows x 2 columns]

# %%
# Mostrar eventos de dividendos
coke.dividends
# Out:
# Date
# 1962-03-13    0.001563
# 1962-06-11    0.001563
# 1962-09-11    0.001563
# 1962-11-28    0.001563
# 1963-03-11    0.001758
#                 ...
# 2021-06-14    0.420000
# 2021-09-14    0.420000
# 2021-11-30    0.420000
# 2022-03-14    0.440000
# 2022-06-14    0.440000
# Name: Dividends, Length: 241, dtype: float64

# %%
# Mostrar demonstrativos financeiros
coke.financials
# Out:
#                                            2021-12-31     2020-12-31  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       12425000000.0   9749000000.0
# Minority Interest                        1861000000.0   1985000000.0
# Net Income                               9771000000.0   7747000000.0
# Selling General Administrative          12144000000.0   9731000000.0
# Gross Profit                            23298000000.0  19581000000.0
# Ebit                                    11161000000.0   9838000000.0
# Operating Income                        11161000000.0   9838000000.0
# Other Operating Expenses                   -7000000.0     12000000.0
# Interest Expense                        -1597000000.0  -1437000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %%
# Mostrar demonstrativos financeiros por trimestres
coke.quarterly_financials
# Out:
#                                            2022-04-01    2021-12-31  \
# Research Development                             None          None
# Effect Of Accounting Charges                     None          None
# Income Before Tax                        3458000000.0  2960000000.0
# Minority Interest                        1996000000.0  1861000000.0
# Net Income                               2781000000.0  2414000000.0
# Selling General Administrative           2967000000.0  3336000000.0
# Gross Profit                             6400000000.0  5376000000.0
# Ebit                                     3433000000.0  2047000000.0
# Operating Income                         3433000000.0  2047000000.0
# Other Operating Expenses                          NaN    -7000000.0
# Interest Expense                         -182000000.0  -165000000.0
# Extraordinary Items                              None          None
# Non Recurring                                    None          None
# ...

# %%
# Mostrar os principais acionistas
coke.major_holders
# Out:
#         0                                      1
# 0   0.66%        % of Shares Held by All Insider
# 1  70.74%       % of Shares Held by Institutions
# 2  71.21%        % of Float Held by Institutions
# 3    3437  Number of Institutions Holding Shares

# %%
# Mostrar acionistas institucionais
coke.institutional_holders
# Out:
#                                        Holder     Shares Date Reported  \
# 0                     Berkshire Hathaway, Inc  400000000    2022-03-30
# 1                  Vanguard Group, Inc. (The)  351220018    2022-03-30
# 2                              Blackrock Inc.  279114132    2022-03-30
# 3                    State Street Corporation  171972013    2022-03-30
# 4                                    FMR, LLC   83088402    2022-03-30
# 5            Wellington Management Group, LLP   80654038    2022-03-30
# 6                   JP Morgan Chase & Company   70822837    2022-03-30
# 7               Geode Capital Management, LLC   70444447    2022-03-30
# 8  Charles Schwab Investment Management, Inc.   51570921    2022-03-30
# 9                              Morgan Stanley   51062192    2022-03-30
#
#     % Out        Value
# 0  0.0923  25175999450
# 1  0.0810  22105787450
# 2  0.0644  17567443084
# 3  0.0397  10823918262
# 4  0.0192   5229583907
# 5  0.0186   5076365040
# ...

# %%
# Mostrar balanço
coke.balance_sheet
# Out:
#                                                 2021-12-31    2020-12-31  \
# Intangible Assets                             1.525000e+10  1.104400e+10
# Capital Surplus                               1.811600e+10  1.760100e+10
# Total Liab                                    6.949400e+10  6.601200e+10
# Total Stockholder Equity                      2.299900e+10  1.929900e+10
# Minority Interest                             1.861000e+09  1.985000e+09
# Other Current Liab                            1.859000e+09  2.010000e+09
# Total Assets                                  9.435400e+10  8.729600e+10
# Common Stock                                  1.760000e+09  1.760000e+09
# Other Current Assets                          1.018000e+09  1.520000e+08
# Retained Earnings                             6.909400e+10  6.655500e+10
# Other Liab                                    1.025300e+10  9.986000e+09
# Good Will                                     1.936300e+10  1.750600e+10
# ...

# %%
# Mostrar balanço trimestral
coke.quarterly_balance_sheet
# Out:
#                                                 2022-04-01    2021-12-31  \
# Intangible Assets                             1.514200e+10  1.525000e+10
# Capital Surplus                               1.838800e+10  1.811600e+10
# Total Liab                                    6.722300e+10  6.949400e+10
# Total Stockholder Equity                      2.484500e+10  2.299900e+10
# Minority Interest                             1.996000e+09  1.861000e+09
# Other Current Liab                            9.740000e+08  1.859000e+09
# Total Assets                                  9.406400e+10  9.435400e+10
# Common Stock                                  1.760000e+09  1.760000e+09
# Other Current Assets                          1.261000e+09  1.018000e+09
# Retained Earnings                             6.996900e+10  6.909400e+10
# Other Liab                                    1.094200e+10  1.025300e+10
# Good Will                                     1.959800e+10  1.936300e+10
# ...

# %%
# Mostrar fluxo de caixa
coke.cashflow
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                                1.029000e+09  2.520000e+08
# Change To Liabilities                      2.843000e+09 -8.600000e+08
# Total Cashflows From Investing Activities -2.765000e+09 -1.477000e+09
# Net Borrowings                             2.280000e+08 -1.862000e+09
# Total Cash From Financing Activities      -6.786000e+09 -8.070000e+09
# Change To Operating Activities            -5.920000e+08  5.850000e+08
# Issuance Of Stock                          7.020000e+08  6.470000e+08
# Net Income                                 9.771000e+09  7.747000e+09
# Change In Cash                             2.915000e+09  3.730000e+08
# Repurchase Of Stock                       -1.110000e+08 -1.180000e+08
# Effect Of Exchange Rate                   -1.590000e+08  7.600000e+07
# Total Cash From Operating Activities       1.262500e+10  9.844000e+09
# ...

# %%
# Mostrar fluxo de caixa
coke.quarterly_cashflow
# Out:
#                                              2022-04-01    2021-12-31  \
# Investments                                4.880000e+08 -1.405000e+09
# Change To Liabilities                      0.000000e+00  2.843000e+09
# Total Cashflows From Investing Activities  1.460000e+08 -4.684000e+09
# Net Borrowings                             7.000000e+06  1.417000e+09
# Total Cash From Financing Activities      -2.975000e+09 -1.950000e+08
# Change To Operating Activities            -2.468000e+09 -7.600000e+08
# Issuance Of Stock                          4.490000e+08  2.090000e+08
# Net Income                                 2.781000e+09  2.414000e+09
# Change In Cash                            -2.033000e+09 -1.588000e+09
# Repurchase Of Stock                       -5.460000e+08 -7.000000e+06
# Effect Of Exchange Rate                    1.730000e+08 -1.030000e+08
# Total Cash From Operating Activities       6.230000e+08  3.394000e+09
# ...

# %%
# Mostrar ganhos
coke.earnings
# Out:
#           Revenue    Earnings
# Year
# 2018  34300000000  6434000000
# 2019  37266000000  8920000000
# 2020  33014000000  7747000000
# 2021  38655000000  9771000000

# %%
# Mostrar ganhos trimestral
coke.quarterly_earnings
# Out:
#              Revenue    Earnings
# Quarter
# 3Q2021   10129000000  2641000000
# 4Q2021   10042000000  2471000000
# 4Q2021    9464000000  2414000000
# 2Q2022   10491000000  2781000000

# %%
# Mostrar calendário de eventos
coke.calendar

# %% [markdown]
# Exemplo com papéis brasileiros

# %%
# BDR APPLE na bolsa brasileira no período de 2017 a 2022
bdr_apple = yf.download('AAPL34.SA',start='2017-01-01',end='2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
bdr_apple.Close.plot()

# %%
# Indice ibovespa no período de 2017 a 2022
ivvb11 = yf.download('IVVB11.SA',start='2017-01-01',end='2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ivvb11.Close.plot()

# %%
# PETR4 no período de 2017 a 2022
petro=yf.download('PETR4.SA',start='2017-01-01',end='2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
petro.Close.plot()
